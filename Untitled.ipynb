# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('input/train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
test=pd.read_csv('input/test.csv')

# %%
y=df['SalePrice']
X=df.drop(['Id','MSSubClass', 'Utilities','LotConfig', 'Condition1', 'Condition2', 'BldgType','Exterior1st', 'Exterior2nd', 'MasVnrType','MasVnrArea','BsmtFinType1', 'BsmtFinSF1','BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF','Functional','FireplaceQu', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea','OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl','ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir','Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea','BsmtFullBath', 'BsmtHalfBath', 'LotFrontage', 'FullBath', 'HalfBath', 'BedroomAbvGr','KitchenAbvGr', 'KitchenQual','GarageQual','PoolArea','GarageCond','Alley', 'PoolQC', 'Fence','3SsnPorch', 'ScreenPorch', 'SalePrice','MiscFeature', 'MiscVal', 'MoSold', 'YrSold'],axis=1)

# %%
X.shape
# Out:
# (1460, 18)

# %%
X.columns
# Out:
# Index(['MSZoning', 'LotArea', 'Street', 'LotShape', 'LandContour', 'LandSlope',
#        'Neighborhood', 'HouseStyle', 'OverallQual', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageType', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
from sklearn import preprocessing
enc = preprocessing.LabelEncoder()

# %%
X.head()
# Out:
#   MSZoning  LotArea Street LotShape LandContour LandSlope Neighborhood  \
# 0       RL     8450   Pave      Reg         Lvl       Gtl      CollgCr
# 1       RL     9600   Pave      Reg         Lvl       Gtl      Veenker
# 2       RL    11250   Pave      IR1         Lvl       Gtl      CollgCr
# 3       RL     9550   Pave      IR1         Lvl       Gtl      Crawfor
# 4       RL    14260   Pave      IR1         Lvl       Gtl      NoRidge
#
#   HouseStyle  OverallQual  TotRmsAbvGrd  Fireplaces GarageType PavedDrive  \
# 0     2Story            7             8           0     Attchd          Y
# 1     1Story            6             6           1     Attchd          Y
# 2     2Story            7             6           1     Attchd          Y
# 3     2Story            7             7           1     Detchd          Y
# 4     2Story            8             9           1     Attchd          Y
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch SaleType SaleCondition
# ...

# %%
X.columns
# Out:
# Index(['MSZoning', 'LotArea', 'Street', 'LotShape', 'LandContour', 'LandSlope',
#        'Neighborhood', 'HouseStyle', 'OverallQual', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageType', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
X
# Out:
#       MSZoning  LotArea Street LotShape LandContour LandSlope Neighborhood  \
# 0            3     8450   Pave      Reg         Lvl       Gtl      CollgCr
# 1            3     9600   Pave      Reg         Lvl       Gtl      Veenker
# 2            3    11250   Pave      IR1         Lvl       Gtl      CollgCr
# 3            3     9550   Pave      IR1         Lvl       Gtl      Crawfor
# 4            3    14260   Pave      IR1         Lvl       Gtl      NoRidge
# 5            3    14115   Pave      IR1         Lvl       Gtl      Mitchel
# 6            3    10084   Pave      Reg         Lvl       Gtl      Somerst
# 7            3    10382   Pave      IR1         Lvl       Gtl       NWAmes
# 8            4     6120   Pave      Reg         Lvl       Gtl      OldTown
# 9            3     7420   Pave      Reg         Lvl       Gtl      BrkSide
# 10           3    11200   Pave      Reg         Lvl       Gtl       Sawyer
# ...

# %%
cat_cols = ['MSZoning', 'LotShape', 'LandContour','LandSlope','Neighborhood', 'HouseStyle','GarageType', 'PavedDrive','SaleType', 'SaleCondition']
enc = preprocessing.LabelEncoder()

for col in cat_cols:
    X[col] = X[col].astype('str')
    test[col] = test[col].astype('str')
    X[col] = enc.fit_transform(X[col])
    test[col] = enc.transform(test[col])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/label.py in _encode_python(values, uniques, encode)
#      67         try:
# ---> 68             encoded = np.array([table[v] for v in values])
#      69         except KeyError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/label.py in <listcomp>(.0)
#      67         try:
# ---> 68             encoded = np.array([table[v] for v in values])
#      69         except KeyError as e:
#
# KeyError: 'nan'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-76a0d3c6041c> in <module>
#       6     test[col] = test[col].astype('str')
#       7     X[col] = enc.fit_transform(X[col])
# ----> 8     test[col] = enc.transform(test[col])
#
# ...

# %%
X
# Out:
#      MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  LandSlope  \
# 0          RL         65.0     8450       1         3            3          0
# 1          RL         80.0     9600       1         3            3          0
# 2          RL         68.0    11250       1         0            3          0
# 3          RL         60.0     9550       1         0            3          0
# 4          RL         84.0    14260       1         0            3          0
# 5          RL         85.0    14115       1         0            3          0
# 6          RL         75.0    10084       1         3            3          0
# 7          RL          NaN    10382       1         0            3          0
# 8          RM         51.0     6120       1         3            3          0
# 9          RL         50.0     7420       1         3            3          0
# 10         RL         70.0    11200       1         3            3          0
# ...
